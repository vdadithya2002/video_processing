# %% [markdown]
# <a href="https://colab.research.google.com/github/vdadithya2002/video_processing/blob/main/advp_morphological.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image in grayscale
img = cv2.imread('pawan.jpg', cv2.IMREAD_GRAYSCALE)

# Apply threshold to get a binary image (required for morphological ops)
_, binary = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# Define kernel (structuring element)
kernel = np.ones((5, 5), np.uint8)

# %% [markdown]
# #erosion

# %%
eroded = cv2.erode(binary, kernel, iterations=1)

# %% [markdown]
# #Dilation

# %%
dilated = cv2.dilate(binary, kernel, iterations=1)

# %% [markdown]
# #Opening (Erosion followed by Dilation)

# %%
opened = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)

# %% [markdown]
# #Closing (Dilation followed by Erosion)

# %%
closed = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)

# %% [markdown]
# #Morphological Gradient

# %%
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)

# %% [markdown]
# #Top Hat

# %%
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)

# %% [markdown]
# #Black Hat

# %%
blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)

# %%
titles = ['Original', 'Binary', 'Eroded', 'Dilated', 'Opened', 'Closed', 'Gradient', 'Top Hat', 'Black Hat']
images = [img, binary, eroded, dilated, opened, closed, gradient, tophat, blackhat]

plt.figure(figsize=(12, 12)) # Increased figure size to accommodate 3x3 grid
for i in range(9):
    plt.subplot(3, 3, i+1) # Changed grid to 3x3
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# #**All in one**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load a grayscale image or binary image
img = cv2.imread('pawan.jpg', cv2.IMREAD_GRAYSCALE)

# Threshold to convert to binary if needed (optional)
_, binary_img = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# Define a kernel (structuring element)
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))

# Apply morphological operations
eroded = cv2.erode(binary_img, kernel, iterations=1)
dilated = cv2.dilate(binary_img, kernel, iterations=1)
opened = cv2.morphologyEx(binary_img, cv2.MORPH_OPEN, kernel)
closed = cv2.morphologyEx(binary_img, cv2.MORPH_CLOSE, kernel)

# Plotting results
plt.figure(figsize=(12, 8))

plt.subplot(2, 3, 1)
plt.title("Original")
plt.imshow(img, cmap='gray')
plt.axis('off')

plt.subplot(2, 3, 2)
plt.title("Binary Image")
plt.imshow(binary_img, cmap='gray')
plt.axis('off')

plt.subplot(2, 3, 3)
plt.title("Erosion")
plt.imshow(eroded, cmap='gray')
plt.axis('off')

plt.subplot(2, 3, 4)
plt.title("Dilation")
plt.imshow(dilated, cmap='gray')
plt.axis('off')

plt.subplot(2, 3, 5)
plt.title("Opening")
plt.imshow(opened, cmap='gray')
plt.axis('off')

plt.subplot(2, 3, 6)
plt.title("Closing")
plt.imshow(closed, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()
